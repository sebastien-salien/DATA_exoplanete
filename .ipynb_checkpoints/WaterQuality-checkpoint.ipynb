# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data =  pd.read_csv('archive/cumulative.csv', index_col=0)
data.head(100)
# Out:
#           kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 3      10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 5      10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...         ...        ...           ...             ...              ...
# 96      3734868  K00805.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 97      3832474  K00806.01   Kepler-30 d       CONFIRMED        CANDIDATE
# 98      8395660  K00116.03  Kepler-106 b       CONFIRMED        CANDIDATE
# 99      3832474  K00806.02   Kepler-30 c       CONFIRMED        CANDIDATE
# 100     3832474  K00806.03   Kepler-30 b       CONFIRMED        CANDIDATE
#
#        koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# rowid
# 1          1.000              0              0              0              0
# 2          0.969              0              0              0              0
# 3          0.000              0              1              0              0
# 4          0.000              0              1              0              0
# 5          1.000              0              0              0              0
# ...          ...            ...            ...            ...            ...
# 96         0.053              0              1              0              0
# 97         1.000              0              0              0              0
# 98         0.950              0              0              0              0
# 99         0.745              0              0              0              0
# 100          NaN              0              0              0              0
#
#        ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# rowid  ...
# 1      ...           -81.0      4.467           0.064          -0.096
# 2      ...           -81.0      4.467           0.064          -0.096
# 3      ...          -176.0      4.544           0.044          -0.176
# 4      ...          -174.0      4.564           0.053          -0.168
# 5      ...          -211.0      4.438           0.070          -0.210
# ...    ...             ...        ...             ...             ...
# 96     ...          -169.0      4.359           0.180          -0.180
# 97     ...          -120.0      4.556           0.014          -0.081
# 98     ...          -117.0      4.406           0.090          -0.110
# 99     ...          -120.0      4.556           0.014          -0.081
# 100    ...          -112.0      4.556           0.014          -0.094
#
#        koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  \
# rowid
# 1         0.927          0.105         -0.061  291.93423  48.141651
# 2         0.927          0.105         -0.061  291.93423  48.141651
# 3         0.868          0.233         -0.078  297.00482  48.134129
# 4         0.791          0.201         -0.067  285.53461  48.285210
# 5         1.046          0.334         -0.133  288.75488  48.226200
# ...         ...            ...            ...        ...        ...
# 96        1.024          0.280         -0.186  287.69675  38.886452
# 97        0.867          0.079         -0.037  285.28363  38.947281
# 98        1.012          0.154         -0.103  300.86398  44.337551
# 99        0.867          0.079         -0.037  285.28363  38.947281
# 100       0.867          0.092         -0.034  285.28363  38.947281
#
#        koi_kepmag
# rowid
# 1          15.347
# 2          15.347
# 3          15.436
# 4          15.597
# 5          15.509
# ...           ...
# 96         15.646
# 97         15.403
# 98         12.882
# 99         15.403
# 100        15.403
#
# [100 rows x 49 columns]

# %%
data.dtypes
# Out:
# rowid                  int64
# kepid                  int64
# kepoi_name            object
# kepler_name           object
# koi_disposition       object
# koi_pdisposition      object
# koi_score            float64
# koi_fpflag_nt          int64
# koi_fpflag_ss          int64
# koi_fpflag_co          int64
# koi_fpflag_ec          int64
# koi_period           float64
# koi_period_err1      float64
# koi_period_err2      float64
# koi_time0bk          float64
# koi_time0bk_err1     float64
# koi_time0bk_err2     float64
# koi_impact           float64
# koi_impact_err1      float64
# koi_impact_err2      float64
# koi_duration         float64
# koi_duration_err1    float64
# koi_duration_err2    float64
# koi_depth            float64
# koi_depth_err1       float64
# koi_depth_err2       float64
# koi_prad             float64
# koi_prad_err1        float64
# koi_prad_err2        float64
# koi_teq              float64
# koi_teq_err1         float64
# koi_teq_err2         float64
# koi_insol            float64
# koi_insol_err1       float64
# koi_insol_err2       float64
# koi_model_snr        float64
# koi_tce_plnt_num     float64
# koi_tce_delivname     object
# koi_steff            float64
# koi_steff_err1       float64
# koi_steff_err2       float64
# koi_slogg            float64
# koi_slogg_err1       float64
# koi_slogg_err2       float64
# koi_srad             float64
# koi_srad_err1        float64
# koi_srad_err2        float64
# ra                   float64
# dec                  float64
# koi_kepmag           float64
# dtype: object

# %%
data.describe()
# Out:
#              rowid         kepid    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count  9564.000000  9.564000e+03  8054.000000    9564.000000    9564.000000
# mean   4782.500000  7.690628e+06     0.480829       0.188206       0.231598
# std    2761.033321  2.653459e+06     0.476928       0.390897       0.421875
# min       1.000000  7.574500e+05     0.000000       0.000000       0.000000
# 25%    2391.750000  5.556034e+06     0.000000       0.000000       0.000000
# 50%    4782.500000  7.906892e+06     0.334000       0.000000       0.000000
# 75%    7173.250000  9.873066e+06     0.998000       0.000000       0.000000
# max    9564.000000  1.293514e+07     1.000000       1.000000       1.000000
#
#        koi_fpflag_co  koi_fpflag_ec     koi_period  koi_period_err1  \
# count    9564.000000    9564.000000    9564.000000      9110.000000
# mean        0.194898       0.120033      75.671358         0.002148
# std         0.396143       0.325018    1334.744046         0.008236
# min         0.000000       0.000000       0.241843         0.000000
# 25%         0.000000       0.000000       2.733684         0.000005
# 50%         0.000000       0.000000       9.752831         0.000035
# 75%         0.000000       0.000000      40.715178         0.000276
# max         1.000000       1.000000  129995.778400         0.172500
#
#        koi_period_err2  ...  koi_steff_err2    koi_slogg  koi_slogg_err1  \
# count      9110.000000  ...     9081.000000  9201.000000     9096.000000
# mean         -0.002148  ...     -162.265059     4.310157        0.120738
# std           0.008236  ...       72.746348     0.432606        0.132837
# min          -0.172500  ...    -1762.000000     0.047000        0.000000
# 25%          -0.000276  ...     -198.000000     4.218000        0.042000
# 50%          -0.000035  ...     -160.000000     4.438000        0.070000
# 75%          -0.000005  ...     -114.000000     4.543000        0.149000
# max           0.000000  ...        0.000000     5.364000        1.472000
#
#        koi_slogg_err2     koi_srad  koi_srad_err1  koi_srad_err2           ra  \
# count     9096.000000  9201.000000    9096.000000    9096.000000  9564.000000
# mean        -0.143161     1.728712       0.362292      -0.394806   292.060163
# std          0.085477     6.127185       0.930870       2.168213     4.766657
# min         -1.207000     0.109000       0.000000    -116.137000   279.852720
# 25%         -0.196000     0.829000       0.129000      -0.250000   288.660770
# 50%         -0.128000     1.000000       0.251000      -0.111000   292.261125
# 75%         -0.088000     1.345000       0.364000      -0.069000   295.859160
# max          0.000000   229.908000      33.091000       0.000000   301.720760
#
#                dec   koi_kepmag
# count  9564.000000  9563.000000
# mean     43.810433    14.264606
# std       3.601243     1.385448
# min      36.577381     6.966000
# 25%      40.777173    13.440000
# 50%      43.677504    14.520000
# 75%      46.714611    15.322000
# max      52.336010    20.003000
#
# [8 rows x 45 columns]

# %%
data.isna().sum()
# Out:
# rowid                   0
# kepid                   0
# kepoi_name              0
# kepler_name          7270
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_teq_err1         9564
# koi_teq_err2         9564
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# koi_tce_plnt_num      346
# koi_tce_delivname     346
# koi_steff             363
# koi_steff_err1        468
# koi_steff_err2        483
# koi_slogg             363
# koi_slogg_err1        468
# koi_slogg_err2        468
# koi_srad              363
# koi_srad_err1         468
# koi_srad_err2         468
# ra                      0
# dec                     0
# koi_kepmag              1
# dtype: int64

# %%
#Cardinalité du JDD
print('data        : {} colonnes ; {} lignes.'.format(data.shape[1],        data.shape[0]))
# Out:
# data        : 50 colonnes ; 9564 lignes.

# %%
## Création de la fonction d'exploration
def Exploration(data):
    """
    """
    cols_names = []
    cols_names.append('Type de variable')
    cols_names.append('Type informatique')
    cols_names.append('Taux de NA (%)')
    cols_names.append('Gestion des NA')
 
    
    # Collecte des informations pour chaque colonne du DataFrame
    dico = {}
    for col in data.columns:
        # 0. Type de variable
        dico[col] = ['TODO']
        
        # 3. Type informatique
        val = str(data[col].dtypes)
        if val == 'object':
            val += ' (' + type(data[col][0]).__name__ + ')'
        dico[col].append(val)
        
        # 4. Taux de NA
        dico[col].append(round(sum(data[col].isna()) / len(data[col]) * 100., 2))
        
        # 5. Gestion des NA
        if dico[col][-1] == 0.:
            dico[col].append('Aucune')
        else:
            dico[col].append('TODO')
        
        
    return pd.DataFrame(np.array([l for l in dico.values()]), columns=cols_names, index=dico.keys())


## Exploration automatique du JDD
data_info = Exploration(data)
data_info
# Out:
#                   Type de variable Type informatique Taux de NA (%)  \
# rowid                         TODO             int64            0.0
# kepid                         TODO             int64            0.0
# kepoi_name                    TODO      object (str)            0.0
# kepler_name                   TODO      object (str)          76.01
# koi_disposition               TODO      object (str)            0.0
# koi_pdisposition              TODO      object (str)            0.0
# koi_score                     TODO           float64          15.79
# koi_fpflag_nt                 TODO             int64            0.0
# koi_fpflag_ss                 TODO             int64            0.0
# koi_fpflag_co                 TODO             int64            0.0
# koi_fpflag_ec                 TODO             int64            0.0
# koi_period                    TODO           float64            0.0
# koi_period_err1               TODO           float64           4.75
# koi_period_err2               TODO           float64           4.75
# koi_time0bk                   TODO           float64            0.0
# koi_time0bk_err1              TODO           float64           4.75
# koi_time0bk_err2              TODO           float64           4.75
# koi_impact                    TODO           float64            3.8
# koi_impact_err1               TODO           float64           4.75
# koi_impact_err2               TODO           float64           4.75
# koi_duration                  TODO           float64            0.0
# koi_duration_err1             TODO           float64           4.75
# koi_duration_err2             TODO           float64           4.75
# koi_depth                     TODO           float64            3.8
# koi_depth_err1                TODO           float64           4.75
# koi_depth_err2                TODO           float64           4.75
# koi_prad                      TODO           float64            3.8
# koi_prad_err1                 TODO           float64            3.8
# koi_prad_err2                 TODO           float64            3.8
# koi_teq                       TODO           float64            3.8
# koi_teq_err1                  TODO           float64          100.0
# koi_teq_err2                  TODO           float64          100.0
# koi_insol                     TODO           float64           3.36
# koi_insol_err1                TODO           float64           3.36
# koi_insol_err2                TODO           float64           3.36
# koi_model_snr                 TODO           float64            3.8
# koi_tce_plnt_num              TODO           float64           3.62
# koi_tce_delivname             TODO      object (str)           3.62
# koi_steff                     TODO           float64            3.8
# koi_steff_err1                TODO           float64           4.89
# koi_steff_err2                TODO           float64           5.05
# koi_slogg                     TODO           float64            3.8
# koi_slogg_err1                TODO           float64           4.89
# koi_slogg_err2                TODO           float64           4.89
# koi_srad                      TODO           float64            3.8
# koi_srad_err1                 TODO           float64           4.89
# koi_srad_err2                 TODO           float64           4.89
# ra                            TODO           float64            0.0
# dec                           TODO           float64            0.0
# koi_kepmag                    TODO           float64           0.01
#
#                   Gestion des NA
# rowid                     Aucune
# kepid                     Aucune
# kepoi_name                Aucune
# kepler_name                 TODO
# koi_disposition           Aucune
# koi_pdisposition          Aucune
# koi_score                   TODO
# koi_fpflag_nt             Aucune
# koi_fpflag_ss             Aucune
# koi_fpflag_co             Aucune
# koi_fpflag_ec             Aucune
# koi_period                Aucune
# koi_period_err1             TODO
# koi_period_err2             TODO
# koi_time0bk               Aucune
# koi_time0bk_err1            TODO
# koi_time0bk_err2            TODO
# koi_impact                  TODO
# koi_impact_err1             TODO
# koi_impact_err2             TODO
# koi_duration              Aucune
# koi_duration_err1           TODO
# koi_duration_err2           TODO
# koi_depth                   TODO
# koi_depth_err1              TODO
# koi_depth_err2              TODO
# koi_prad                    TODO
# koi_prad_err1               TODO
# koi_prad_err2               TODO
# koi_teq                     TODO
# koi_teq_err1                TODO
# koi_teq_err2                TODO
# koi_insol                   TODO
# koi_insol_err1              TODO
# koi_insol_err2              TODO
# koi_model_snr               TODO
# koi_tce_plnt_num            TODO
# koi_tce_delivname           TODO
# koi_steff                   TODO
# koi_steff_err1              TODO
# koi_steff_err2              TODO
# koi_slogg                   TODO
# koi_slogg_err1              TODO
# koi_slogg_err2              TODO
# koi_srad                    TODO
# koi_srad_err1               TODO
# koi_srad_err2               TODO
# ra                        Aucune
# dec                       Aucune
# koi_kepmag                  TODO

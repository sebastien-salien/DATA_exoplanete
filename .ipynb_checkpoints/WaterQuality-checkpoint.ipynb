# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score, confusion_matrix, plot_confusion_matrix

# %%
data =  pd.read_csv('archive/water_potability.csv' )
data.head(100)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# ..       ...         ...           ...          ...         ...           ...
# 95  6.140878  197.876090  26687.874483     7.587196  329.231853    548.072761
# 96  7.077874  220.670540  23873.378210     6.181840  341.987234    333.050786
# 97  5.488314  135.802362  21485.153195     8.187416  280.603287    441.331137
# 98  7.205559  120.327615  24627.867560     6.202469  289.768697    418.433290
# 99  9.177870  163.274828  20868.331219     7.726040  320.421432    426.994393
#
#     Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0        10.379783        86.990970   2.963135           0
# 1        15.180013        56.329076   4.500656           0
# 2        16.868637        66.420093   3.055934           0
# 3        18.436524       100.341674   4.628771           0
# 4        11.558279        31.997993   4.075075           0
# ..             ...              ...        ...         ...
# 95       15.836330        41.263648   5.359460           0
# 96       10.661799        90.297770   4.764508           0
# 97       14.860263        88.287346   5.066786           0
# 98       13.643147        63.733732   3.710053           0
# 99       10.214275        62.430926   3.108770           0
#
# [100 rows x 10 columns]

# %%
data.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
print(data.isnull().sum())
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
data = data.drop(columns="Sulfate",axis=1)
data["ph"].fillna(value = data["ph"].mean(), inplace = True)
data["Trihalomethanes"].fillna(value = data["Trihalomethanes"].mean(), inplace = True)

print(data.isnull().sum())
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
#Cardinalité du JDD
print('data        : {} colonnes ; {} lignes.'.format(data.shape[1],        data.shape[0]))
# Out:
# data        : 9 colonnes ; 3276 lignes.

# %%
## Création de la fonction d'exploration
def Exploration(data):
    """
    """
    cols_names = []
    cols_names.append('Type de variable')
    cols_names.append('Type informatique')
    cols_names.append('Taux de NA (%)')
    cols_names.append('Gestion des NA')
 
    
    # Collecte des informations pour chaque colonne du DataFrame
    dico = {}
    for col in data.columns:
        # 0. Type de variable
        dico[col] = ['TODO']
        
        # 3. Type informatique
        val = str(data[col].dtypes)
        if val == 'object':
            val += ' (' + type(data[col][0]).__name__ + ')'
        dico[col].append(val)
        
        # 4. Taux de NA
        dico[col].append(round(sum(data[col].isna()) / len(data[col]) * 100., 2))
        
        # 5. Gestion des NA
        if dico[col][-1] == 0.:
            dico[col].append('Aucune')
        else:
            dico[col].append('TODO')
        
        
    return pd.DataFrame(np.array([l for l in dico.values()]), columns=cols_names, index=dico.keys())


## Exploration automatique du JDD
data_info = Exploration(data)
data_info
# Out:
#                 Type de variable Type informatique Taux de NA (%)  \
# ph                          TODO           float64            0.0
# Hardness                    TODO           float64            0.0
# Solids                      TODO           float64            0.0
# Chloramines                 TODO           float64            0.0
# Conductivity                TODO           float64            0.0
# Organic_carbon              TODO           float64            0.0
# Trihalomethanes             TODO           float64            0.0
# Turbidity                   TODO           float64            0.0
# Potability                  TODO             int64            0.0
#
#                 Gestion des NA
# ph                      Aucune
# Hardness                Aucune
# Solids                  Aucune
# Chloramines             Aucune
# Conductivity            Aucune
# Organic_carbon          Aucune
# Trihalomethanes         Aucune
# Turbidity               Aucune
# Potability              Aucune

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(data.corr(), annot=True, cmap='RdBu_r', center=0);

# %%
non_potable = data.query("Potability == 0")
potable = data.query("Potability == 1")

plt.figure(figsize = (15,15))

plt.subplot(2,2,1)
plt.title('ph')
sns.kdeplot(x = non_potable['ph'], label = "Non Potable")
plt.legend()


plt.subplot(2,2,2)
plt.title('ph')
sns.kdeplot(x = potable['ph'], label = "Potable")
plt.legend()

# %%
non_potable = data.query("Potability == 0")
potable = data.query("Potability == 1")

plt.hist(potable.ph)
plt.show()

# %%
non_potable = data.query("Potability == 0")
potable = data.query("Potability == 1")

plt.figure(figsize = (15,15))
for ax, col in enumerate(data.columns[:9]):
    plt.subplot(3,3, ax + 1)
    plt.title(col)
    plt.hist([potable[col],non_potable[col]], bins = 10, label = ['potable', 'non potable'])
    plt.legend()

# %%
data_r = data.drop(columns="Potability",axis=1)
target = data['Potability']

# %%
X_train, X_test, y_train, y_test = train_test_split(data_r, target, test_size = 0.2,random_state=44)

# %%
lreg = linear_model.LogisticRegression()
lreg.fit(X_train, y_train)
y_pred = lreg.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)

print('Accuracy (%): ', accuracy * 100)
print(classification_report(y_test,y_pred))
plot_confusion_matrix(lreg, X_test, y_test)
# Out:
# Accuracy (%):  62.5
#               precision    recall  f1-score   support
#
#            0       0.63      1.00      0.77       411
#            1       0.00      0.00      0.00       245
#
#     accuracy                           0.62       656
#    macro avg       0.31      0.50      0.38       656
# weighted avg       0.39      0.62      0.48       656

# %% [markdown]
# # Model Regression Logistique
#
# ce model n'est pas adequate a notre base de donnée. en effert, elle retourne une accuracy de 62,5%. De plus le rappel pour la potabilité est a 0.

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(max_depth = 3)
dtc.fit(X_train, y_train)
y_pred = dtc.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)

print('Accuracy (%): ', accuracy * 100)
print(classification_report(y_test,y_pred))
plot_confusion_matrix(dtc, X_test, y_test)
# Out:
# Accuracy (%):  62.95731707317073
#               precision    recall  f1-score   support
#
#            0       0.63      0.99      0.77       411
#            1       0.57      0.03      0.06       245
#
#     accuracy                           0.63       656
#    macro avg       0.60      0.51      0.42       656
# weighted avg       0.61      0.63      0.51       656

# %% [markdown]
# # Model Decision Tree

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)

print('Accuracy (%): ', accuracy * 100)
print(classification_report(y_test,y_pred))
plot_confusion_matrix(rfc, X_test, y_test)
# Out:
# Accuracy (%):  64.32926829268293
#               precision    recall  f1-score   support
#
#            0       0.67      0.85      0.75       411
#            1       0.54      0.30      0.38       245
#
#     accuracy                           0.64       656
#    macro avg       0.61      0.57      0.57       656
# weighted avg       0.62      0.64      0.61       656

# %% [markdown]
# # Model Random Forest
